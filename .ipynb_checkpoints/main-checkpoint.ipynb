# %%
import product
import graph
import provider

# %%
list_providers = provider.feed_providers(3)
list_products = product.feed_products(list_providers, 100)
T = product.feed_T_matrice(list_products)
B = product.feed_B_matrice(T)
product.write_matrice("test2.txt", T)

# %%
g = graph.matrice_to_graph("test2.txt")

# %%
keys, res, mincut = graph.krager2(B, g, 3)
# Out:
# choosen edge: B[12][59] = 54
# choosen edge: B[42][1] = 49
# choosen edge: B[11][81] = 97
# choosen edge: B[30][94] = 74
# choosen edge: B[8][36] = 79
# choosen edge: B[5][25] = 39
# choosen edge: B[9][86] = 36
# choosen edge: B[12][64] = 71
# choosen edge: B[78][52] = 11
# choosen edge: B[20][70] = 65
# choosen edge: B[78][91] = 27
# choosen edge: B[6][49] = 76
# choosen edge: B[12][77] = 84
# choosen edge: B[51][16] = 69
# choosen edge: B[8][83] = 73
# choosen edge: B[85][84] = 99
# choosen edge: B[44][37] = 62
# choosen edge: B[63][8] = 43
# choosen edge: B[30][48] = 61
# choosen edge: B[14][9] = 123
# choosen edge: B[30][95] = 75
# choosen edge: B[92][15] = 51
# choosen edge: B[55][92] = 33
# choosen edge: B[20][51] = 50
# choosen edge: B[2][62] = 79
# choosen edge: B[90][6] = 87
# choosen edge: B[34][44] = 42
# choosen edge: B[99][71] = 98
# choosen edge: B[10][53] = 77
# choosen edge: B[32][98] = 80
# choosen edge: B[5][67] = 21
# choosen edge: B[30][10] = 132
# choosen edge: B[63][20] = 246
# choosen edge: B[93][32] = 78
# choosen edge: B[57][63] = 94
# choosen edge: B[54][18] = 52
# choosen edge: B[46][11] = 63
# choosen edge: B[30][74] = 101
# choosen edge: B[90][33] = 93
# choosen edge: B[72][22] = 15
# choosen edge: B[14][46] = 348
# choosen edge: B[55][42] = 50
# choosen edge: B[45][87] = 96
# choosen edge: B[90][12] = 221
# choosen edge: B[5][45] = 198
# choosen edge: B[72][26] = 85
# choosen edge: B[78][90] = 220
# choosen edge: B[73][79] = 69
# choosen edge: B[5][30] = 154
# choosen edge: B[55][61] = 69
# choosen edge: B[58][40] = 37
# choosen edge: B[78][5] = 1820
# choosen edge: B[89][80] = 58
# choosen edge: B[55][78] = 1213
# choosen edge: B[13][35] = 59
# choosen edge: B[55][89] = 502
# choosen edge: B[55][57] = 3023
# choosen edge: B[55][93] = 996
# choosen edge: B[55][14] = 2062
# choosen edge: B[55][17] = 674
# choosen edge: B[60][75] = 95
# choosen edge: B[34][55] = 1272
# choosen edge: B[24][34] = 543
# choosen edge: B[24][13] = 1177
# choosen edge: B[76][56] = 81
# choosen edge: B[72][24] = 1877
# choosen edge: B[72][2] = 1223
# choosen edge: B[47][72] = 652
# choosen edge: B[47][88] = 533
# choosen edge: B[54][47] = 1039
# choosen edge: B[27][54] = 443
# choosen edge: B[23][21] = 43
# choosen edge: B[66][27] = 535
# choosen edge: B[38][66] = 645
# choosen edge: B[28][43] = 95
# choosen edge: B[38][28] = 1343
# choosen edge: B[0][38] = 474
# choosen edge: B[0][41] = 419
# choosen edge: B[0][99] = 1341
# choosen edge: B[4][23] = 33
# choosen edge: B[0][4] = 2062
# choosen edge: B[39][0] = 836
# choosen edge: B[39][60] = 1620
# choosen edge: B[39][29] = 814
# choosen edge: B[69][39] = 935
# choosen edge: B[97][69] = 995
# choosen edge: B[58][97] = 1580
# choosen edge: B[58][7] = 746
# choosen edge: B[85][82] = 139
# choosen edge: B[76][58] = 1691
# choosen edge: B[76][3] = 926
# choosen edge: B[76][19] = 627
# choosen edge: B[50][76] = 408
# choosen edge: B[85][50] = 2058
# choosen edge: B[73][85] = 1582
# choosen edge: B[73][68] = 1340
# choosen edge: B[65][73] = 660

# %%
best_mincut, best_graph, best_partition, mincuts = graph.repe_krager2(B, g, 3, 2)
# Out:
# RÉPÉTITION 1
# choosen edge: B[48][73] = 92
# choosen edge: B[88][36] = 97
# choosen edge: B[47][29] = 44
# choosen edge: B[40][59] = 39
# choosen edge: B[67][32] = 51
# choosen edge: B[40][69] = 47
# choosen edge: B[52][40] = 34
# choosen edge: B[60][65] = 56
# choosen edge: B[48][43] = 62
# choosen edge: B[53][50] = 7
# choosen edge: B[35][62] = 77
# choosen edge: B[60][70] = 95
# choosen edge: B[0][8] = 37
# choosen edge: B[68][0] = 26
# choosen edge: B[17][33] = 96
# choosen edge: B[53][95] = 92
# choosen edge: B[56][55] = 83
# choosen edge: B[89][26] = 72
# choosen edge: B[20][60] = 86
# choosen edge: B[18][22] = 27
# choosen edge: B[21][61] = 96
# choosen edge: B[41][86] = 44
# choosen edge: B[10][76] = 22
# choosen edge: B[66][17] = 37
# choosen edge: B[34][27] = 89
# choosen edge: B[88][24] = 67
# choosen edge: B[53][66] = 76
# choosen edge: B[54][20] = 134
# choosen edge: B[91][84] = 48
# choosen edge: B[99][15] = 95
# choosen edge: B[21][30] = 85
# choosen edge: B[97][16] = 100
# choosen edge: B[78][54] = 23
# choosen edge: B[88][53] = 118
# choosen edge: B[6][38] = 66
# choosen edge: B[56][45] = 47
# choosen edge: B[87][67] = 88
# choosen edge: B[58][75] = 61
# choosen edge: B[88][89] = 207
# choosen edge: B[47][88] = 296
# choosen edge: B[21][92] = 94
# choosen edge: B[47][12] = 46
# choosen edge: B[47][87] = 749
# choosen edge: B[68][14] = 97
# choosen edge: B[23][13] = 99
# choosen edge: B[68][47] = 648
# choosen edge: B[56][68] = 705
# choosen edge: B[2][5] = 62
# choosen edge: B[46][56] = 286
# choosen edge: B[11][46] = 345
# choosen edge: B[80][21] = 74
# choosen edge: B[85][11] = 321
# choosen edge: B[42][90] = 57
# choosen edge: B[52][85] = 1010
# choosen edge: B[42][91] = 90
# choosen edge: B[52][6] = 397
# choosen edge: B[9][80] = 73
# choosen edge: B[42][52] = 1673
# choosen edge: B[42][23] = 1053
# choosen edge: B[2][42] = 744
# choosen edge: B[98][78] = 79
# choosen edge: B[44][2] = 473
# choosen edge: B[44][93] = 469
# choosen edge: B[10][44] = 673
# choosen edge: B[10][7] = 609
# choosen edge: B[10][98] = 2717
# choosen edge: B[10][34] = 1636
# choosen edge: B[71][79] = 13
# choosen edge: B[10][74] = 623
# choosen edge: B[10][57] = 417
# choosen edge: B[48][51] = 83
# choosen edge: B[48][10] = 1879
# choosen edge: B[48][39] = 603
# choosen edge: B[48][9] = 3621
# choosen edge: B[48][41] = 1193
# choosen edge: B[48][1] = 901
# choosen edge: B[77][48] = 715
# choosen edge: B[77][63] = 684
# choosen edge: B[77][18] = 1588
# choosen edge: B[77][71] = 1615
# choosen edge: B[35][77] = 1358
# choosen edge: B[72][35] = 881
# choosen edge: B[72][4] = 1044
# choosen edge: B[97][72] = 1228
# choosen edge: B[28][97] = 886
# choosen edge: B[96][28] = 742
# choosen edge: B[96][99] = 1687
# choosen edge: B[94][64] = 94
# choosen edge: B[96][82] = 668
# choosen edge: B[94][96] = 1619
# choosen edge: B[94][19] = 484
# choosen edge: B[58][31] = 57
# choosen edge: B[94][81] = 975
# choosen edge: B[83][94] = 447
# choosen edge: B[83][49] = 1103
# choosen edge: B[58][83] = 2045
# choosen edge: B[58][25] = 1303
# RÉPÉTITION 2
# choosen edge: B[58][3] = 626
# choosen edge: B[37][58] = 453
# ----------------------------------------------------------------------
# ValueError                           Traceback (most recent call last)
# <ipython-input-82-30e148d2d1dc> in <module>
# ----> 1 best_mincut, best_graph, best_partition, mincuts = graph.repe_krager2(B, g, 3, 2)
#
# ~/Documents/GI05/Algo_pb_dif/TP1/graph.py in repe_krager2(B, graph, r, k, seed)
#     254         print("RÉPÉTITION " + str(i+1))
#     255         graph_copy = copy.deepcopy(graph)
# --> 256         B_copy = B
#     257         print(B_copy)
#     258         list_graph_key, part, mincut = krager2(B_copy, graph_copy, r)
#
# ~/Documents/GI05/Algo_pb_dif/TP1/graph.py in krager2(B, graph, r)
#     227     U = []
#     228     while(len(graph) > r):
# --> 229         edge = get_edge(B)
#     230         (v1, v2) = edge
#     231         res = include(res, U, edge)
#
# ~/Documents/GI05/Algo_pb_dif/TP1/graph.py in get_edge(B)
#     188     proba = np.array(B).flatten()
#     189     proba = proba / proba.sum(axis=0, keepdims=1)
# --> 190     index = np.random.choice(index_arr, p=proba)
#     191     i = index//len(B)
#     192     j = index%len(B)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: probabilities contain NaN
